# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
b_df=pd.read_excel("banking_data.xlsx")
b_df
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
b_df.rename(columns=b_df.iloc[1], inplace = True)

# %%
b_df.drop([0,1],inplace=True)

# %%
b_df.reset_index()
# Out:
#        index customerid age  salary balance   marital                  jobedu  \
# 0          2          1  58  100000    2143   married     management,tertiary
# 1          3          2  44   60000      29    single    technician,secondary
# 2          4          3  33  120000       2   married  entrepreneur,secondary
# 3          5          4  47   20000    1506   married     blue-collar,unknown
# 4          6          5  33       0       1    single         unknown,unknown
# ...      ...        ...  ..     ...     ...       ...                     ...
# 45206  45208      45207  51   60000     825   married     technician,tertiary
# 45207  45209      45208  71   55000    1729  divorced         retired,primary
# 45208  45210      45209  72   55000    5715   married       retired,secondary
# 45209  45211      45210  57   20000     668   married   blue-collar,secondary
# 45210  45212      45211  37  120000    2971   married  entrepreneur,secondary
#
# ...

# %%
df1 = df[df['Age'] >= 37]

# %%
b_df[['job','education']]=b_df['jobedu'].str.split(",",expand=True)

# %%
b_df.drop(['jobedu'],axis=1,inplace=True)

# %%
b_df[['month','year']]=b_df['month'].str.split(",",expand=True)

# %%
b_df
# Out:
#       customerid age  salary balance   marital targeted default housing loan  \
# 2              1  58  100000    2143   married      yes      no     yes   no
# 3              2  44   60000      29    single      yes      no     yes   no
# 4              3  33  120000       2   married      yes      no     yes  yes
# 5              4  47   20000    1506   married       no      no     yes   no
# 6              5  33       0       1    single       no      no      no   no
# ...          ...  ..     ...     ...       ...      ...     ...     ...  ...
# 45208      45207  51   60000     825   married      yes      no      no   no
# 45209      45208  71   55000    1729  divorced      yes      no      no   no
# 45210      45209  72   55000    5715   married      yes      no      no   no
# 45211      45210  57   20000     668   married      yes      no      no   no
# 45212      45211  37  120000    2971   married      yes      no      no   no
#
# ...

# %%
b_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45211 entries, 2 to 45212
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  object
#  1   age         45191 non-null  object
#  2   salary      45211 non-null  object
#  3   balance     45211 non-null  object
#  4   marital     45211 non-null  object
#  5   targeted    45211 non-null  object
#  6   default     45211 non-null  object
#  7   housing     45211 non-null  object
#  8   loan        45211 non-null  object
#  9   contact     45211 non-null  object
#  10  day         45211 non-null  object
#  11  month       45161 non-null  object
#  12  duration    45211 non-null  object
#  13  campaign    45211 non-null  object
#  14  pdays       45211 non-null  object
#  15  previous    45211 non-null  object
#  16  poutcome    45211 non-null  object
#  17  response    45181 non-null  object
#  18  job         45211 non-null  object
# ...

# %%
b_df.isna().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# education      0
# year          50
# dtype: int64

# %%
#b_df["age"] = pd.to_numeric(b_df["age"])
#
#

b_df['salary'] = b_df['salary'].replace(['?'],'0')

# %%
b_df["salary"] = pd.to_numeric(b_df["salary"])
b_df["balance"] = pd.to_numeric(b_df["balance"])

b_df["campaign"] = pd.to_numeric(b_df["campaign"])
b_df["pdays"] = pd.to_numeric(b_df["pdays"])
b_df["previous"] = pd.to_numeric(b_df["previous"])

# %%
b_df.salary.value_counts()
# Out:
# 20000     9732
# 100000    9458
# 60000     9176
# 50000     5171
# 70000     4154
# 55000     2264
# 120000    1487
# 8000      1303
# 16000     1240
# 4000       938
# 0          226
# 0           62
# Name: salary, dtype: int64

# %%
b_df.dtypes
# Out:
# customerid     object
# age           float64
# salary          int64
# balance         int64
# marital        object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day            object
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# job            object
# education      object
# year           object
# dtype: object

# %%
b_df.describe()
# Out:
#                 age         salary        balance      campaign         pdays  \
# count  45191.000000   45211.000000   45211.000000  45211.000000  45211.000000
# mean      40.935651   57006.171065    1362.272058      2.763841     40.197828
# std       10.619198   32085.718415    3044.765829      3.098021    100.128746
# min       18.000000       0.000000   -8019.000000      1.000000     -1.000000
# 25%       33.000000   20000.000000      72.000000      1.000000     -1.000000
# 50%       39.000000   60000.000000     448.000000      2.000000     -1.000000
# 75%       48.000000   70000.000000    1428.000000      3.000000     -1.000000
# max       95.000000  120000.000000  102127.000000     63.000000    871.000000
#
#            previous
# count  45211.000000
# mean       0.580323
# std        2.303441
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
min_thresold, max_thresold = df.salary.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (4000.0, 120000.0)

# %%
df[df.salary<min_thresold]
# Out:
#       customerid      age  salary  balance   marital targeted default housing  \
# 6              5 33.00000       0        1    single       no      no      no
# 218          217 47.00000       0       28   married       no      no      no
# 356          355 59.00000       0       27  divorced       no      no      no
# 878          877 37.00000       0      414    single       no      no     yes
# 1074        1073 29.00000       0       50    single      yes      no     yes
# ...          ...      ...     ...      ...       ...      ...     ...     ...
# 44716      44715 45.00000       0      406   married      yes      no      no
# 44744      44743 64.00000       0     2799   married       no      no      no
# 44972      44971 28.00000       0      326    single       no      no      no
# 45143      45142 77.00000       0      397   married       no      no      no
# 45188      45187 59.00000       0     1500   married       no      no      no
#
# ...

# %%
df2 = df[(df.salary>min_thresold)&(df.salary<max_thresold)]
df2.shape
# Out:
# customerid     object
# age           float64
# salary          int64
# balance         int64
# marital        object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day            object
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# job            object
# education      object
# year           object
# dtype: object

# %%
df2.sample(5)
# Out:
#       customerid      age  salary  balance   marital targeted default housing  \
# 37190      37189 36.00000   70000      413   married      yes      no     yes
# 23683      23682 42.00000   60000        0   married      yes      no      no
# 26634      26633 39.00000   70000     1957  divorced      yes      no     yes
# 14712      14711 35.00000   50000     2622    single       no      no      no
# 43495      43494 34.00000  100000      589   married      yes      no      no
#
#       loan    contact  ... month               duration campaign  pdays  \
# 37190   no  telephone  ...   may                  1 min        1    176
# 23683   no   cellular  ...   aug  0.583333333333333 min       13     -1
# 26634  yes   cellular  ...   nov  0.783333333333333 min        1     -1
# 14712   no   cellular  ...   jul   6.23333333333333 min        5     -1
# 43495   no   cellular  ...   apr   2.08333333333333 min        2     -1
#
# ...

# %%
df2.salary.describe()
# Out:
# count    42403.00000
# mean     56361.10653
# std      29532.90312
# min       8000.00000
# 25%      20000.00000
# 50%      60000.00000
# 75%      70000.00000
# max     100000.00000
# Name: salary, dtype: float64

# %%
df2.balance.describe()
# Out:
# count    42403.00000
# mean      1353.52560
# std       3012.13579
# min      -8019.00000
# 25%         71.00000
# 50%        449.00000
# 75%       1419.00000
# max     102127.00000
# Name: balance, dtype: float64

# %%
min_thresold_bal, max_thresold_bal = df.balance.quantile([0.03,0.999])
min_thresold_bal, max_thresold_bal
# Out:
# (-322.0, 32919.07000000176)

# %%
df3 = df[(df.balance>min_thresold_bal)&(df.balance<max_thresold_bal)]
df3.shape
# Out:
# (43708, 21)

# %%
df3.balance.describe()
# Out:
# count   43708.00000
# mean     1374.06145
# std      2594.90443
# min      -321.00000
# 25%        96.75000
# 50%       481.00000
# 75%      1482.25000
# max     32685.00000
# Name: balance, dtype: float64

# %%
df=b_df.dropna()

# %%
df.poutcome.value_counts()
# Out:
# unknown    36877
# failure     4890
# other       1839
# success     1505
# Name: poutcome, dtype: int64

# %%
num=df.poutcome.value_counts()
num
plt.figure(figsize=(20,6))
plt.pie(num,labels=["unknown","failure","other","success"],autopct="%.2f%%");

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df.groupby(['poutcome'])['age'].mean().plot(kind='bar',color="orange")
# Out:
# <AxesSubplot:xlabel='poutcome'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45111 entries, 2 to 45212
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45111 non-null  object
#  1   age         45111 non-null  float64
#  2   salary      45111 non-null  int64
#  3   balance     45111 non-null  int64
#  4   marital     45111 non-null  object
#  5   targeted    45111 non-null  object
#  6   default     45111 non-null  object
#  7   housing     45111 non-null  object
#  8   loan        45111 non-null  object
#  9   contact     45111 non-null  object
#  10  day         45111 non-null  object
#  11  month       45111 non-null  object
#  12  duration    45111 non-null  object
#  13  campaign    45111 non-null  int64
#  14  pdays       45111 non-null  int64
#  15  previous    45111 non-null  int64
#  16  poutcome    45111 non-null  object
#  17  response    45111 non-null  object
#  18  job         45111 non-null  object
# ...

# %%
#average salary according to marital
df.groupby(['marital'])['salary'].mean().plot(kind='line')
#divorced people has high average salary and married has low average salary
# Out:
# <AxesSubplot:xlabel='marital'>

# %%
#average marital age 
df.groupby(['marital'])['age'].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='marital'>

# %%
df.head()
# Out:
#   customerid      age  salary  balance  marital targeted default housing loan  \
# 2          1 58.00000  100000     2143  married      yes      no     yes   no
# 3          2 44.00000   60000       29   single      yes      no     yes   no
# 4          3 33.00000  120000        2  married      yes      no     yes  yes
# 5          4 47.00000   20000     1506  married       no      no     yes   no
# 6          5 33.00000       0        1   single       no      no      no   no
#
#    contact  ... month duration campaign  pdays  previous  poutcome response  \
# 2  unknown  ...   may  261 sec        1     -1         0   unknown       no
# 3  unknown  ...   may  151 sec        1     -1         0   unknown       no
# 4  unknown  ...   may   76 sec        1     -1         0   unknown       no
# 5  unknown  ...   may   92 sec        1     -1         0   unknown       no
# 6  unknown  ...   may  198 sec        1     -1         0   unknown       no
#
#             job  education   year
# ...

# %%
df.groupby(['marital'])['campaign'].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='marital'>

# %%
d=pd.crosstab(index = df.month, columns=df.poutcome, margins=True)
d.max()
# Out:
# poutcome
# failure     4890
# other       1839
# success     1505
# unknown    36877
# All        45111
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap = 'summer', annot=True);
#correlation between data
